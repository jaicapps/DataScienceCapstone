# %%
import nn_functions
import pandas as pd

# %%
x_train, x_test, y_train, y_test, predictors = nn_functions.get_data('../../plutoPCA_land.csv','assessland')

# %%
input_nodes = len(predictors)
epochs = 20
hidden_nodes = [int((input_nodes+1)*(2/3)), int(len(x_train)/(30*2)), int(len(x_train)/(30*4)), int(len(x_train)/(30*6)), int(len(x_train)/(30*8))]
optimizers = ['rmsprop', 'adam', 'sgd','adagrad','adadelta']
h = []
o = []
df_models = pd.DataFrame()
for i in hidden_nodes:
    for j in optimizers:
        h.append(i)
        o.append(j)
        
df_models['hidden_nodes'] = h
df_models['optimizer']  = o
df_models
# Out:
#     hidden_nodes optimizer
# 0            114   rmsprop
# 1            114      adam
# 2            114       sgd
# 3            114   adagrad
# 4            114  adadelta
# 5            207   rmsprop
# 6            207      adam
# 7            207       sgd
# 8            207   adagrad
# 9            207  adadelta
# 10           103   rmsprop
# 11           103      adam
# 12           103       sgd
# 13           103   adagrad
# 14           103  adadelta
# 15            69   rmsprop
# 16            69      adam
# 17            69       sgd
# 18            69   adagrad
# 19            69  adadelta
# 20            51   rmsprop
# 21            51      adam
# 22            51       sgd
# 23            51   adagrad
# 24            51  adadelta

# %%
mse_list = []
rmse_list = []
r2_list = []
error_list = []
for index, row in df_models.iterrows():
    try:
        print('Model:', index, 'hidden_nodes:', row['hidden_nodes'], 'optimizer:', row['optimizer'])
        y_train_pred, y_test_pred, mse,rmse,r2,error = nn_functions.run_model(input_nodes, row['hidden_nodes'], x_train, x_test, y_train, y_test, row['optimizer'], epochs)
    except Exception as ex:
        print(ex)
        mse = float('nan')
        rmse = float('nan')
        r2 = float('nan')
        error = float('nan')
        print('Error while computing model: ', index)
    mse_list.append(mse)
    rmse_list.append(rmse)
    r2_list.append(r2)
    error_list.append(error)
        
df_models['mse'] = mse_list
df_models['rmse'] = rmse_list
df_models['r2'] = r2_list
df_models['error'] = error_list
# Out:
# Model: 0 hidden_nodes: 114 optimizer: rmsprop
# ERROR Training
# mse 2197553185.948
# RMSE 46878.067
# R2 0.529
# error 1946.8667366267268
# ERROR Test
# mse 1993087766.437
# RMSE 44644.012
# R2 0.409
# error 1160.767545700687
# Histogram Training
# Histogram Test
# Model: 1 hidden_nodes: 114 optimizer: adam
# ERROR Training
# mse 2060274732.373
# RMSE 45390.249
# R2 0.558
# error -951.1119661702579
# ERROR Test
# mse 2251648229.755
# RMSE 47451.536
# R2 0.332
# error -1707.941971001938
# Histogram Training
# Histogram Test
# Model: 2 hidden_nodes: 114 optimizer: sgd
# ERROR Training
# Input contains NaN, infinity or a value too large for dtype('float32').
# Error while computing model:  2
# Model: 3 hidden_nodes: 114 optimizer: adagrad
# ERROR Training
# mse 5130817265.522
# RMSE 71629.723
# R2 -0.1
# error 21790.36954352893
# ERROR Test
# mse 3836474726.967
# RMSE 61939.283
# R2 -0.138
# error 21768.508401021878
# Histogram Training
# Histogram Test
# Model: 4 hidden_nodes: 114 optimizer: adadelta
# ERROR Training
# mse 5145613765.136
# RMSE 71732.934
# R2 -0.103
# error 21892.552024500055
# ERROR Test
# mse 3850680749.129
# RMSE 62053.854
# R2 -0.142
# error 21873.49555576835
# Histogram Training
# Histogram Test
# Model: 5 hidden_nodes: 207 optimizer: rmsprop
# ERROR Training
# mse 2129795340.104
# RMSE 46149.706
# R2 0.544
# error 1244.6617859509315
# ERROR Test
# mse 2018396197.924
# RMSE 44926.565
# R2 0.401
# error 504.3778007854366
# Histogram Training
# Histogram Test
# Model: 6 hidden_nodes: 207 optimizer: adam
# ERROR Training
# mse 2002662483.818
# RMSE 44751.117
# R2 0.571
# error -414.1412969735953
# ERROR Test
# mse 2270560775.979
# RMSE 47650.402
# R2 0.327
# error -1293.5449810445386
# Histogram Training
# Histogram Test
# Model: 7 hidden_nodes: 207 optimizer: sgd
# ERROR Training
# Input contains NaN, infinity or a value too large for dtype('float32').
# Error while computing model:  7
# Model: 8 hidden_nodes: 207 optimizer: adagrad
# ERROR Training
# mse 5116058126.596
# RMSE 71526.625
# R2 -0.096
# error 21690.002564840073
# ERROR Test
# mse 3822253251.247
# RMSE 61824.374
# R2 -0.133
# error 21665.475375633472
# Histogram Training
# Histogram Test
# Model: 9 hidden_nodes: 207 optimizer: adadelta
# ERROR Training
# mse 5145617667.081
# RMSE 71732.961
# R2 -0.103
# error 21892.83654891655
# ERROR Test
# mse 3850684545.386
# RMSE 62053.884
# R2 -0.142
# error 21873.7825080792
# Histogram Training
# Histogram Test
# Model: 10 hidden_nodes: 103 optimizer: rmsprop
# ERROR Training
# mse 2216051163.062
# RMSE 47074.953
# R2 0.525
# error 2329.610648516236
# ERROR Test
# mse 1991275694.713
# RMSE 44623.712
# R2 0.41
# error 1570.1974867217175
# Histogram Training
# Histogram Test
# Model: 11 hidden_nodes: 103 optimizer: adam
# ERROR Training
# mse 2069946699.963
# RMSE 45496.667
# R2 0.556
# error -1059.5641170191082
# ERROR Test
# mse 2197849550.673
# RMSE 46881.228
# R2 0.348
# error -1790.364925134136
# Histogram Training
# Histogram Test
# Model: 12 hidden_nodes: 103 optimizer: sgd
# ERROR Training
# Input contains NaN, infinity or a value too large for dtype('float32').
# Error while computing model:  12
# Model: 13 hidden_nodes: 103 optimizer: adagrad
# ERROR Training
# mse 5132400015.899
# RMSE 71640.771
# R2 -0.1
# error 21802.739473202426
# ERROR Test
# mse 3838109222.297
# RMSE 61952.476
# R2 -0.138
# error 21781.867589517675
# Histogram Training
# Histogram Test
# Model: 14 hidden_nodes: 103 optimizer: adadelta
# ERROR Training
# mse 5145585199.405
# RMSE 71732.735
# R2 -0.103
# error 21892.350410703973
# ERROR Test
# mse 3850654364.157
# RMSE 62053.641
# R2 -0.142
# error 21873.29114707484
# Histogram Training
# Histogram Test
# Model: 15 hidden_nodes: 69 optimizer: rmsprop
# ERROR Training
# mse 2244646631.921
# RMSE 47377.702
# R2 0.519
# error 1929.6391278155218
# ERROR Test
# mse 1951127413.353
# RMSE 44171.568
# R2 0.421
# error 1217.4934078194153
# Histogram Training
# Histogram Test
# Model: 16 hidden_nodes: 69 optimizer: adam
# ERROR Training
# mse 2116759020.975
# RMSE 46008.249
# R2 0.546
# error -929.0908949219379
# ERROR Test
# mse 2193028156.056
# RMSE 46829.779
# R2 0.35
# error -1647.6826270310883
# Histogram Training
# Histogram Test
# Model: 17 hidden_nodes: 69 optimizer: sgd
# ERROR Training
# Input contains NaN, infinity or a value too large for dtype('float32').
# Error while computing model:  17
# Model: 18 hidden_nodes: 69 optimizer: adagrad
# ERROR Training
# mse 5137473454.473
# RMSE 71676.171
# R2 -0.101
# error 21837.28653151507
# ERROR Test
# mse 3842931049.421
# RMSE 61991.379
# R2 -0.14
# error 21817.057367193385
# Histogram Training
# Histogram Test
# Model: 19 hidden_nodes: 69 optimizer: adadelta
# ERROR Training
# mse 5145639373.138
# RMSE 71733.112
# R2 -0.103
# error 21893.016389530367
# ERROR Test
# mse 3850705721.298
# RMSE 62054.055
# R2 -0.142
# error 21873.96895685455
# Histogram Training
# Histogram Test
# Model: 20 hidden_nodes: 51 optimizer: rmsprop
# ERROR Training
# mse 2294756027.611
# RMSE 47903.612
# R2 0.508
# error 2114.3354194234107
# ERROR Test
# mse 1912395077.891
# RMSE 43730.94
# R2 0.433
# error 1471.590445777471
# Histogram Training
# Histogram Test
# Model: 21 hidden_nodes: 51 optimizer: adam
# ERROR Training
# mse 2148079899.756
# RMSE 46347.383
# R2 0.54
# error -285.34565734249395
# ERROR Test
# mse 2146507778.509
# RMSE 46330.42
# R2 0.363
# error -1002.0691209152399
# Histogram Training
# Histogram Test
# Model: 22 hidden_nodes: 51 optimizer: sgd
# ERROR Training
# Input contains NaN, infinity or a value too large for dtype('float32').
# Error while computing model:  22
# Model: 23 hidden_nodes: 51 optimizer: adagrad
# ERROR Training
# mse 5138369170.035
# RMSE 71682.419
# R2 -0.101
# error 21844.30120175128
# ERROR Test
# mse 3843688228.556
# RMSE 61997.486
# R2 -0.14
# error 21824.023308692278
# Histogram Training
# Histogram Test
# Model: 24 hidden_nodes: 51 optimizer: adadelta
# ERROR Training
# mse 5145633598.436
# RMSE 71733.072
# R2 -0.103
# error 21892.947844218936
# ERROR Test
# mse 3850700017.158
# RMSE 62054.009
# R2 -0.142
# error 21873.89383476087
# Histogram Training
# Histogram Test

# %%
min_r2 = df_models['r2'].idxmax(axis=0, skipna=True)
print('Min r2:', min_r2)
print(df_models.loc[min_r2])
max_rmse = df_models['rmse'].idxmin(axis=0, skipna=True)
print('Min rmse:', max_rmse)
print(df_models.loc[max_rmse])
df_models
# Out:
# Min r2: 20
# hidden_nodes            51
# optimizer          rmsprop
# mse             1.9124e+09
# rmse               43730.9
# r2                   0.433
# error              1471.59
# Name: 20, dtype: object
# Min rmse: 20
# hidden_nodes            51
# optimizer          rmsprop
# mse             1.9124e+09
# rmse               43730.9
# r2                   0.433
# error              1471.59
# Name: 20, dtype: object
#     hidden_nodes optimizer           mse       rmse     r2         error
# 0            114   rmsprop  1.993088e+09  44644.012  0.409   1160.767546
# 1            114      adam  2.251648e+09  47451.536  0.332  -1707.941971
# 2            114       sgd           NaN        NaN    NaN           NaN
# 3            114   adagrad  3.836475e+09  61939.283 -0.138  21768.508401
# 4            114  adadelta  3.850681e+09  62053.854 -0.142  21873.495556
# 5            207   rmsprop  2.018396e+09  44926.565  0.401    504.377801
# 6            207      adam  2.270561e+09  47650.402  0.327  -1293.544981
# 7            207       sgd           NaN        NaN    NaN           NaN
# 8            207   adagrad  3.822253e+09  61824.374 -0.133  21665.475376
# 9            207  adadelta  3.850685e+09  62053.884 -0.142  21873.782508
# 10           103   rmsprop  1.991276e+09  44623.712  0.410   1570.197487
# 11           103      adam  2.197850e+09  46881.228  0.348  -1790.364925
# 12           103       sgd           NaN        NaN    NaN           NaN
# 13           103   adagrad  3.838109e+09  61952.476 -0.138  21781.867590
# 14           103  adadelta  3.850654e+09  62053.641 -0.142  21873.291147
# 15            69   rmsprop  1.951127e+09  44171.568  0.421   1217.493408
# 16            69      adam  2.193028e+09  46829.779  0.350  -1647.682627
# 17            69       sgd           NaN        NaN    NaN           NaN
# 18            69   adagrad  3.842931e+09  61991.379 -0.140  21817.057367
# 19            69  adadelta  3.850706e+09  62054.055 -0.142  21873.968957
# 20            51   rmsprop  1.912395e+09  43730.940  0.433   1471.590446
# 21            51      adam  2.146508e+09  46330.420  0.363  -1002.069121
# 22            51       sgd           NaN        NaN    NaN           NaN
# 23            51   adagrad  3.843688e+09  61997.486 -0.140  21824.023309
# 24            51  adadelta  3.850700e+09  62054.009 -0.142  21873.893835
