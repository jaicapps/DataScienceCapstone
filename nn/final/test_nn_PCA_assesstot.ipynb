# %%
import nn_functions
import pandas as pd

# %%
x_train, x_test, y_train, y_test, predictors = nn_functions.get_data('../../plutoPCA_tot.csv','assesstot')

# %%
input_nodes = len(predictors)
epochs = 20
hidden_nodes = [int((input_nodes+1)*(2/3)), int(len(x_train)/(30*2)), int(len(x_train)/(30*4)), int(len(x_train)/(30*6)), int(len(x_train)/(30*8))]
optimizers = ['rmsprop', 'adam', 'sgd','adagrad','adadelta']
h = []
o = []
df_models = pd.DataFrame()
for i in hidden_nodes:
    for j in optimizers:
        h.append(i)
        o.append(j)
        
df_models['hidden_nodes'] = h
df_models['optimizer']  = o
df_models
# Out:
#     hidden_nodes optimizer
# 0            114   rmsprop
# 1            114      adam
# 2            114       sgd
# 3            114   adagrad
# 4            114  adadelta
# 5            207   rmsprop
# 6            207      adam
# 7            207       sgd
# 8            207   adagrad
# 9            207  adadelta
# 10           103   rmsprop
# 11           103      adam
# 12           103       sgd
# 13           103   adagrad
# 14           103  adadelta
# 15            69   rmsprop
# 16            69      adam
# 17            69       sgd
# 18            69   adagrad
# 19            69  adadelta
# 20            51   rmsprop
# 21            51      adam
# 22            51       sgd
# 23            51   adagrad
# 24            51  adadelta

# %%
mse_list = []
rmse_list = []
r2_list = []
error_list = []
for index, row in df_models.iterrows():
    try:
        print('Model:', index, 'hidden_nodes:', row['hidden_nodes'], 'optimizer:', row['optimizer'])
        y_train_pred, y_test_pred, mse,rmse,r2,error = nn_functions.run_model(input_nodes, row['hidden_nodes'], x_train, x_test, y_train, y_test, row['optimizer'], epochs)
    except Exception as ex:
        print(ex)
        mse = float('nan')
        rmse = float('nan')
        r2 = float('nan')
        error = float('nan')
        print('Error while computing model: ', index)
    mse_list.append(mse)
    rmse_list.append(rmse)
    r2_list.append(r2)
    error_list.append(error)
        
df_models['mse'] = mse_list
df_models['rmse'] = rmse_list
df_models['r2'] = r2_list
df_models['error'] = error_list
# Out:
# Model: 0 hidden_nodes: 114 optimizer: rmsprop
# ERROR Training
# mse 36400180731.182
# RMSE 190788.314
# R2 0.678
# error 2359.62459118588
# ERROR Test
# mse 30359159016.724
# RMSE 174238.799
# R2 0.677
# error 1575.9761393852675
# Histogram Training
# Histogram Test
# Model: 1 hidden_nodes: 114 optimizer: adam
# ERROR Training
# mse 33162169976.13
# RMSE 182104.832
# R2 0.706
# error -609.6583278886051
# ERROR Test
# mse 28433859204.31
# RMSE 168623.424
# R2 0.697
# error -2220.1281511633247
# Histogram Training
# Histogram Test
# Model: 2 hidden_nodes: 114 optimizer: sgd
# ERROR Training
# Input contains NaN, infinity or a value too large for dtype('float32').
# Error while computing model:  2
# Model: 3 hidden_nodes: 114 optimizer: adagrad
# ERROR Training
# mse 122332039507.793
# RMSE 349759.974
# R2 -0.083
# error 97111.05317505875
# ERROR Test
# mse 103157090117.571
# RMSE 321180.775
# R2 -0.098
# error 96166.12365320222
# Histogram Training
# Histogram Test
# Model: 4 hidden_nodes: 114 optimizer: adadelta
# ERROR Training
# mse 122424770485.878
# RMSE 349892.513
# R2 -0.084
# error 97183.03817792374
# ERROR Test
# mse 103241281851.111
# RMSE 321311.814
# R2 -0.099
# error 96240.01171888808
# Histogram Training
# Histogram Test
# Model: 5 hidden_nodes: 207 optimizer: rmsprop
# ERROR Training
# mse 34715223933.856
# RMSE 186320.219
# R2 0.693
# error 4606.94788277013
# ERROR Test
# mse 29025424297.157
# RMSE 170368.496
# R2 0.691
# error 3894.544416101129
# Histogram Training
# Histogram Test
# Model: 6 hidden_nodes: 207 optimizer: adam
# ERROR Training
# mse 31271205982.105
# RMSE 176836.665
# R2 0.723
# error -933.6638258340698
# ERROR Test
# mse 27330345179.42
# RMSE 165318.92
# R2 0.709
# error -2123.85330848252
# Histogram Training
# Histogram Test
# Model: 7 hidden_nodes: 207 optimizer: sgd
# ERROR Training
# Input contains NaN, infinity or a value too large for dtype('float32').
# Error while computing model:  7
# Model: 8 hidden_nodes: 207 optimizer: adagrad
# ERROR Training
# mse 122248511244.07
# RMSE 349640.546
# R2 -0.082
# error 97041.81047997615
# ERROR Test
# mse 103081482727.535
# RMSE 321063.051
# R2 -0.097
# error 96095.59138649025
# Histogram Training
# Histogram Test
# Model: 9 hidden_nodes: 207 optimizer: adadelta
# ERROR Training
# mse 122424672748.242
# RMSE 349892.373
# R2 -0.084
# error 97183.09432225436
# ERROR Test
# mse 103241189363.107
# RMSE 321311.67
# R2 -0.099
# error 96240.06336666083
# Histogram Training
# Histogram Test
# Model: 10 hidden_nodes: 103 optimizer: rmsprop
# ERROR Training
# mse 36655269742.486
# RMSE 191455.66
# R2 0.676
# error 3032.7585912912577
# ERROR Test
# mse 30245883465.691
# RMSE 173913.437
# R2 0.678
# error 2233.3386865466105
# Histogram Training
# Histogram Test
# Model: 11 hidden_nodes: 103 optimizer: adam
# ERROR Training
# mse 33359322040.111
# RMSE 182645.345
# R2 0.705
# error -1403.631248853964
# ERROR Test
# mse 28648375651.638
# RMSE 169258.31
# R2 0.695
# error -3071.6641044174844
# Histogram Training
# Histogram Test
# Model: 12 hidden_nodes: 103 optimizer: sgd
# ERROR Training
# Input contains NaN, infinity or a value too large for dtype('float32').
# Error while computing model:  12
# Model: 13 hidden_nodes: 103 optimizer: adagrad
# ERROR Training
# mse 122328104336.757
# RMSE 349754.349
# R2 -0.083
# error 97105.8355468999
# ERROR Test
# mse 103153382354.031
# RMSE 321175.003
# R2 -0.098
# error 96160.87804238197
# Histogram Training
# Histogram Test
# Model: 14 hidden_nodes: 103 optimizer: adadelta
# ERROR Training
# mse 122424618241.512
# RMSE 349892.295
# R2 -0.084
# error 97182.86763524167
# ERROR Test
# mse 103241121758.581
# RMSE 321311.565
# R2 -0.099
# error 96239.8220633422
# Histogram Training
# Histogram Test
# Model: 15 hidden_nodes: 69 optimizer: rmsprop
# ERROR Training
# mse 38478631535.378
# RMSE 196159.709
# R2 0.659
# error 1773.2483231299248
# ERROR Test
# mse 31480357970.646
# RMSE 177427.05
# R2 0.665
# error 782.2484025304689
# Histogram Training
# Histogram Test
# Model: 16 hidden_nodes: 69 optimizer: adam
# ERROR Training
# mse 35108301299.657
# RMSE 187372.093
# R2 0.689
# error -2371.7457424749373
# ERROR Test
# mse 29781003691.946
# RMSE 172571.735
# R2 0.683
# error -4430.0325224101925
# Histogram Training
# Histogram Test
# Model: 17 hidden_nodes: 69 optimizer: sgd
# ERROR Training
# Input contains NaN, infinity or a value too large for dtype('float32').
# Error while computing model:  17
# Model: 18 hidden_nodes: 69 optimizer: adagrad
# ERROR Training
# mse 122363448405.812
# RMSE 349804.872
# R2 -0.083
# error 97134.30973277354
# ERROR Test
# mse 103185309554.647
# RMSE 321224.703
# R2 -0.098
# error 96189.96052606415
# Histogram Training
# Histogram Test
# Model: 19 hidden_nodes: 69 optimizer: adadelta
# ERROR Training
# mse 122424595124.233
# RMSE 349892.262
# R2 -0.084
# error 97182.7066135524
# ERROR Test
# mse 103241125166.89
# RMSE 321311.57
# R2 -0.099
# error 96239.66642152949
# Histogram Training
# Histogram Test
# Model: 20 hidden_nodes: 51 optimizer: rmsprop
# ERROR Training
# mse 39233633271.564
# RMSE 198074.817
# R2 0.653
# error -457.30252573180894
# ERROR Test
# mse 32145171356.102
# RMSE 179290.745
# R2 0.658
# error -1528.215828059723
# Histogram Training
# Histogram Test
# Model: 21 hidden_nodes: 51 optimizer: adam
# ERROR Training
# mse 36227780836.997
# RMSE 190335.968
# R2 0.679
# error -3388.26650033367
# ERROR Test
# mse 30587073478.833
# RMSE 174891.605
# R2 0.675
# error -5617.287003210306
# Histogram Training
# Histogram Test
# Model: 22 hidden_nodes: 51 optimizer: sgd
# ERROR Training
# Input contains NaN, infinity or a value too large for dtype('float32').
# Error while computing model:  22
# Model: 23 hidden_nodes: 51 optimizer: adagrad
# ERROR Training
# mse 122376806808.236
# RMSE 349823.965
# R2 -0.083
# error 97145.73741957457
# ERROR Test
# mse 103197794487.67
# RMSE 321244.135
# R2 -0.098
# error 96201.6782691956
# Histogram Training
# Histogram Test
# Model: 24 hidden_nodes: 51 optimizer: adadelta
# ERROR Training
# mse 122424489075.447
# RMSE 349892.111
# R2 -0.084
# error 97182.78030187887
# ERROR Test
# mse 103241044312.497
# RMSE 321311.444
# R2 -0.099
# error 96239.75067572344
# Histogram Training
# Histogram Test

# %%
min_r2 = df_models['r2'].idxmax(axis=0, skipna=True)
print('Min r2:', min_r2)
print(df_models.loc[min_r2])
max_rmse = df_models['rmse'].idxmin(axis=0, skipna=True)
print('Min rmse:', max_rmse)
print(df_models.loc[max_rmse])
df_models
# Out:
# Min r2: 6
# hidden_nodes            207
# optimizer              adam
# mse             2.73303e+10
# rmse                 165319
# r2                    0.709
# error              -2123.85
# Name: 6, dtype: object
# Min rmse: 6
# hidden_nodes            207
# optimizer              adam
# mse             2.73303e+10
# rmse                 165319
# r2                    0.709
# error              -2123.85
# Name: 6, dtype: object
#     hidden_nodes optimizer           mse        rmse     r2         error
# 0            114   rmsprop  3.035916e+10  174238.799  0.677   1575.976139
# 1            114      adam  2.843386e+10  168623.424  0.697  -2220.128151
# 2            114       sgd           NaN         NaN    NaN           NaN
# 3            114   adagrad  1.031571e+11  321180.775 -0.098  96166.123653
# 4            114  adadelta  1.032413e+11  321311.814 -0.099  96240.011719
# 5            207   rmsprop  2.902542e+10  170368.496  0.691   3894.544416
# 6            207      adam  2.733035e+10  165318.920  0.709  -2123.853308
# 7            207       sgd           NaN         NaN    NaN           NaN
# 8            207   adagrad  1.030815e+11  321063.051 -0.097  96095.591386
# 9            207  adadelta  1.032412e+11  321311.670 -0.099  96240.063367
# 10           103   rmsprop  3.024588e+10  173913.437  0.678   2233.338687
# 11           103      adam  2.864838e+10  169258.310  0.695  -3071.664104
# 12           103       sgd           NaN         NaN    NaN           NaN
# 13           103   adagrad  1.031534e+11  321175.003 -0.098  96160.878042
# 14           103  adadelta  1.032411e+11  321311.565 -0.099  96239.822063
# 15            69   rmsprop  3.148036e+10  177427.050  0.665    782.248403
# 16            69      adam  2.978100e+10  172571.735  0.683  -4430.032522
# 17            69       sgd           NaN         NaN    NaN           NaN
# 18            69   adagrad  1.031853e+11  321224.703 -0.098  96189.960526
# 19            69  adadelta  1.032411e+11  321311.570 -0.099  96239.666422
# 20            51   rmsprop  3.214517e+10  179290.745  0.658  -1528.215828
# 21            51      adam  3.058707e+10  174891.605  0.675  -5617.287003
# 22            51       sgd           NaN         NaN    NaN           NaN
# 23            51   adagrad  1.031978e+11  321244.135 -0.098  96201.678269
# 24            51  adadelta  1.032410e+11  321311.444 -0.099  96239.750676
