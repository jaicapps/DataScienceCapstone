# %%
import nn_functions
import pandas as pd

# %%
x_train, x_test, y_train, y_test, predictors = nn_functions.get_data('../../plutoPCA_tot.csv','assesstot')

# %%
input_nodes = len(predictors)
epochs = 20
hidden_nodes = [int((input_nodes+1)*(2/3)), int(len(x_train)/(30*2)), int(len(x_train)/(30*4)), int(len(x_train)/(30*6)), int(len(x_train)/(30*8))]
optimizers = ['rmsprop', 'adam','adagrad','adadelta']
h = []
o = []
df_models = pd.DataFrame()
for i in hidden_nodes:
    for j in optimizers:
        h.append(i)
        o.append(j)
        
df_models['hidden_nodes'] = h
df_models['optimizer']  = o
df_models
# Out:
#     hidden_nodes optimizer
# 0            114   rmsprop
# 1            114      adam
# 2            114   adagrad
# 3            114  adadelta
# 4            207   rmsprop
# 5            207      adam
# 6            207   adagrad
# 7            207  adadelta
# 8            103   rmsprop
# 9            103      adam
# 10           103   adagrad
# 11           103  adadelta
# 12            69   rmsprop
# 13            69      adam
# 14            69   adagrad
# 15            69  adadelta
# 16            51   rmsprop
# 17            51      adam
# 18            51   adagrad
# 19            51  adadelta

# %%
mse_list = []
rmse_list = []
r2_list = []
error_list = []
for index, row in df_models.iterrows():
    try:
        print('Model:', index, 'hidden_nodes:', row['hidden_nodes'], 'optimizer:', row['optimizer'])
        y_train_pred, y_test_pred, mse,rmse,r2,error = nn_functions.run_model(input_nodes, row['hidden_nodes'], x_train, x_test, y_train, y_test, row['optimizer'], epochs)
    except Exception as ex:
        print(ex)
        mse = float('nan')
        rmse = float('nan')
        r2 = float('nan')
        error = float('nan')
        print('Error while computing model: ', index)
    mse_list.append(mse)
    rmse_list.append(rmse)
    r2_list.append(r2)
    error_list.append(error)
        
df_models['mse'] = mse_list
df_models['rmse'] = rmse_list
df_models['r2'] = r2_list
df_models['error'] = error_list
# Out:
# Model: 0 hidden_nodes: 114 optimizer: rmsprop
# ERROR Training
# mse 36328414716.305
# RMSE 190600.144
# R2 0.678
# error 2809.455661544088
# ERROR Test
# mse 30228674727.063
# RMSE 173863.955
# R2 0.678
# error 1871.0848766091246
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 1 hidden_nodes: 114 optimizer: adam
# ERROR Training
# mse 33223561651.039
# RMSE 182273.316
# R2 0.706
# error -543.075778282222
# ERROR Test
# mse 28485983554.633
# RMSE 168777.912
# R2 0.697
# error -2183.2260448107236
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 2 hidden_nodes: 114 optimizer: adagrad
# ERROR Training
# mse 122328186473.497
# RMSE 349754.466
# R2 -0.083
# error 97105.62892621932
# ERROR Test
# mse 103153752734.179
# RMSE 321175.579
# R2 -0.098
# error 96160.48051249396
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 3 hidden_nodes: 114 optimizer: adadelta
# ERROR Training
# mse 122424663320.198
# RMSE 349892.36
# R2 -0.084
# error 97182.84573402605
# ERROR Test
# mse 103241189503.586
# RMSE 321311.67
# R2 -0.099
# error 96239.82566760709
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 4 hidden_nodes: 207 optimizer: rmsprop
# ERROR Training
# mse 34653964380.681
# RMSE 186155.753
# R2 0.693
# error 4037.190143908714
# ERROR Test
# mse 29051606091.14
# RMSE 170445.317
# R2 0.691
# error 3172.6702084375243
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 5 hidden_nodes: 207 optimizer: adam
# ERROR Training
# mse 31373448509.366
# RMSE 177125.516
# R2 0.722
# error -3701.3711936651107
# ERROR Test
# mse 27157242052.812
# RMSE 164794.545
# R2 0.711
# error -4883.176827999002
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 6 hidden_nodes: 207 optimizer: adagrad
# ERROR Training
# mse 122236346008.743
# RMSE 349623.149
# R2 -0.082
# error 97028.52863517575
# ERROR Test
# mse 103069982353.26
# RMSE 321045.141
# R2 -0.097
# error 96082.19977999903
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 7 hidden_nodes: 207 optimizer: adadelta
# ERROR Training
# mse 122424717085.887
# RMSE 349892.436
# R2 -0.084
# error 97183.13243770646
# ERROR Test
# mse 103241231144.502
# RMSE 321311.735
# R2 -0.099
# error 96240.0946952224
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 8 hidden_nodes: 103 optimizer: rmsprop
# ERROR Training
# mse 36619813577.671
# RMSE 191363.041
# R2 0.676
# error 2168.0640804425652
# ERROR Test
# mse 30316892184.126
# RMSE 174117.467
# R2 0.677
# error 1275.5824087016679
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 9 hidden_nodes: 103 optimizer: adam
# ERROR Training
# mse 33628345944.917
# RMSE 183380.331
# R2 0.702
# error -2251.6486590683203
# ERROR Test
# mse 28783868266.358
# RMSE 169658.092
# R2 0.694
# error -3967.1965281403163
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 10 hidden_nodes: 103 optimizer: adagrad
# ERROR Training
# mse 122332899648.171
# RMSE 349761.204
# R2 -0.083
# error 97110.25213448989
# ERROR Test
# mse 103157833251.566
# RMSE 321181.932
# R2 -0.098
# error 96165.14612692632
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 11 hidden_nodes: 103 optimizer: adadelta
# ERROR Training
# mse 122424453724.912
# RMSE 349892.06
# R2 -0.084
# error 97182.68722927639
# ERROR Test
# mse 103240978070.441
# RMSE 321311.341
# R2 -0.099
# error 96239.63571434705
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 12 hidden_nodes: 69 optimizer: rmsprop
# ERROR Training
# mse 38081932575.494
# RMSE 195145.926
# R2 0.663
# error 2327.596839923202
# ERROR Test
# mse 31234064123.728
# RMSE 176731.616
# R2 0.668
# error 1304.9422840329516
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 13 hidden_nodes: 69 optimizer: adam
# ERROR Training
# mse 34822566562.423
# RMSE 186608.056
# R2 0.692
# error -1613.5305569234063
# ERROR Test
# mse 29584536730.428
# RMSE 172001.56
# R2 0.685
# error -3543.7718631543094
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 14 hidden_nodes: 69 optimizer: adagrad
# ERROR Training
# mse 122372410482.172
# RMSE 349817.682
# R2 -0.083
# error 97140.14783068109
# ERROR Test
# mse 103193915162.516
# RMSE 321238.097
# R2 -0.098
# error 96196.27513250819
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 15 hidden_nodes: 69 optimizer: adadelta
# ERROR Training
# mse 122424614564.68
# RMSE 349892.29
# R2 -0.084
# error 97182.92870129732
# ERROR Test
# mse 103241136053.994
# RMSE 321311.587
# R2 -0.099
# error 96239.8915981211
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 16 hidden_nodes: 51 optimizer: rmsprop
# ERROR Training
# mse 39193478831.05
# RMSE 197973.43
# R2 0.653
# error -40.148367365802414
# ERROR Test
# mse 32072820393.564
# RMSE 179088.862
# R2 0.659
# error -1084.8224925651207
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 17 hidden_nodes: 51 optimizer: adam
# ERROR Training
# mse 36146005556.55
# RMSE 190121.029
# R2 0.68
# error -3889.169598490086
# ERROR Test
# mse 30582216391.64
# RMSE 174877.718
# R2 0.675
# error -6024.565615536777
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 18 hidden_nodes: 51 optimizer: adagrad
# ERROR Training
# mse 122366907625.152
# RMSE 349809.816
# R2 -0.083
# error 97137.57296771757
# ERROR Test
# mse 103188666924.335
# RMSE 321229.928
# R2 -0.098
# error 96193.26513433066
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test
# Model: 19 hidden_nodes: 51 optimizer: adadelta
# ERROR Training
# mse 122424777986.996
# RMSE 349892.523
# R2 -0.084
# error 97182.99241807462
# ERROR Test
# mse 103241296736.592
# RMSE 321311.837
# R2 -0.099
# error 96239.9663264834
# Histogram Training
# Histogram Test
# Histogram Training
# Histogram Test

# %%
min_r2 = df_models['r2'].idxmax(axis=0, skipna=True)
print('Min r2:', min_r2)
print(df_models.loc[min_r2])
max_rmse = df_models['rmse'].idxmin(axis=0, skipna=True)
print('Min rmse:', max_rmse)
print(df_models.loc[max_rmse])
df_models
# Out:
# Min r2: 5
# hidden_nodes            207
# optimizer              adam
# mse             2.71572e+10
# rmse                 164795
# r2                    0.711
# error              -4883.18
# Name: 5, dtype: object
# Min rmse: 5
# hidden_nodes            207
# optimizer              adam
# mse             2.71572e+10
# rmse                 164795
# r2                    0.711
# error              -4883.18
# Name: 5, dtype: object
#     hidden_nodes optimizer           mse        rmse     r2         error
# 0            114   rmsprop  3.022867e+10  173863.955  0.678   1871.084877
# 1            114      adam  2.848598e+10  168777.912  0.697  -2183.226045
# 2            114   adagrad  1.031538e+11  321175.579 -0.098  96160.480512
# 3            114  adadelta  1.032412e+11  321311.670 -0.099  96239.825668
# 4            207   rmsprop  2.905161e+10  170445.317  0.691   3172.670208
# 5            207      adam  2.715724e+10  164794.545  0.711  -4883.176828
# 6            207   adagrad  1.030700e+11  321045.141 -0.097  96082.199780
# 7            207  adadelta  1.032412e+11  321311.735 -0.099  96240.094695
# 8            103   rmsprop  3.031689e+10  174117.467  0.677   1275.582409
# 9            103      adam  2.878387e+10  169658.092  0.694  -3967.196528
# 10           103   adagrad  1.031578e+11  321181.932 -0.098  96165.146127
# 11           103  adadelta  1.032410e+11  321311.341 -0.099  96239.635714
# 12            69   rmsprop  3.123406e+10  176731.616  0.668   1304.942284
# 13            69      adam  2.958454e+10  172001.560  0.685  -3543.771863
# 14            69   adagrad  1.031939e+11  321238.097 -0.098  96196.275133
# 15            69  adadelta  1.032411e+11  321311.587 -0.099  96239.891598
# 16            51   rmsprop  3.207282e+10  179088.862  0.659  -1084.822493
# 17            51      adam  3.058222e+10  174877.718  0.675  -6024.565616
# 18            51   adagrad  1.031887e+11  321229.928 -0.098  96193.265134
# 19            51  adadelta  1.032413e+11  321311.837 -0.099  96239.966326
